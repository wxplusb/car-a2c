# %%
import car.env as e
import matplotlib.pyplot as plt
import numpy as np

# %%
env = e.Env(seed=12)
state = env.reset()
env.render_area()

# %%
env.render(state)

# %%
action = 7
state, reward, done, info = env.step(action)
print(reward, done, info)
env.render(state)
# Out:
# 1.0 False {'truncated': False, 'finished': False, 'velosity': 1.0, 'reason': None}

# %%
action = 7
state, reward, done, info = env.step(action)
print(reward, done, info)
env.render(state)
# Out:
# 3.48 False {'truncated': False, 'finished': False, 'velosity': 2.0, 'reason': None}

# %%
action = 7
state, reward, done, info = env.step(action)
print(reward, done, info)
env.render(state)
# Out:
# 7.22 False {'truncated': False, 'finished': False, 'velosity': 3.0, 'reason': None}

# %%
action = 8
state, reward, done, info = env.step(action)
print(reward, done, info)
env.render(state)
# Out:
# 12.81 False {'truncated': False, 'finished': False, 'velosity': 4.123105625617661, 'reason': None}

# %%
action = 8
state, reward, done, info = env.step(action)
print(reward, done, info)
env.render(state)
# Out:
# 20.71 False {'truncated': False, 'finished': False, 'velosity': 5.385164807134504, 'reason': None}

# %%
action = 5
state, reward, done, info = env.step(action)
print(reward, done, info)
env.render(state)
# Out:
# 23.9 False {'truncated': False, 'finished': False, 'velosity': 5.830951894845301, 'reason': None}

# %%
action = 5
state, reward, done, info = env.step(action)
print(reward, done, info)
env.render(state)
# Out:
# 28.28 False {'truncated': False, 'finished': False, 'velosity': 6.4031242374328485, 'reason': None}

# %%
action = 5
state, reward, done, info = env.step(action)
print(reward, done, info)
env.render(state)
# Out:
# -108.86163694558756 False {'truncated': False, 'finished': False, 'velosity': 7.0710678118654755, 'reason': None}

# %%
action = 5
state, reward, done, info = env.step(action)
print(reward, done, info)
env.render(state)
# Out:
# -30 True {'truncated': False, 'finished': False, 'velosity': 7.810249675906654, 'reason': 'lawn'}
